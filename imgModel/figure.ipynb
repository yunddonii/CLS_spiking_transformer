# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from IPython.core.display import HTML
import matplotlib
from matplotlib import font_manager
import shutil

# %%
sorted([font.name for font in font_manager.fontManager.ttflist])
# Out:
# ['Abyssinica SIL',
#  'Ani',
#  'AnjaliOldLipi',
#  'C059',
#  'C059',
#  'C059',
#  'C059',
#  'Chandas',
#  'Chilanka',
#  'D050000L',
#  'DejaVu Math TeX Gyre',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans',
#  'DejaVu Sans Display',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif',
#  'DejaVu Serif Display',
#  'Droid Sans Fallback',
#  'Dyuthi',
#  'FreeMono',
#  'FreeMono',
#  'FreeMono',
#  'FreeMono',
#  'FreeSans',
#  'FreeSans',
# ...

# %%
# plt.rcParams.update({
#     'text.usetex' : True
# })
# plt.rc('text', usetex=True)

# %%
# plt.rcParams['font.family'] = 'serif'
# plt.rcParams["figure.figsize"] = (6, 4)
# plt.rcParams['lines.linewidth'] = 1.5

# plt.rcParams['xtick.labelsize'] = 10
# plt.rcParams['ytick.labelsize'] = 10
# plt.rcParams['axes.ymargin'] = 0.5

 
# x = range(2, 6)
# f, ax  = plt.subplots(1, 1)

## epoch 250 기록
# plt.plot(x, [97.95, 97.83, 98.00, 97.87], color = '#4269D0FF', marker = 'o', markersize= 6, label = '64' )
# plt.plot(x, [98.23, 98.00, 97.90, 97.85], color = '#EFB118FF', marker = 'o', markersize= 6, label = '72' )
# plt.plot(x, [98.31, 98.13, 98.20, 98.08], color = '#FF8AB7FF', marker = 'o', markersize= 6, label = '96' )
# # sns.lineplot(x = 'The number of layers', y = 'Energy consumption (uJ)', data = pd.DataFrame([10, 20, 30, 40]), color = 'b', marker = '^', markersize= 12, label = 'After No.1 sample')
 
# #ax.set(xscale="log", yscale="linear")
# #ax.get_xaxis().get_major_formatter().labelOnlyBase = False

# ax.set_xlabel('The number of layers in Neocortex', fontdict={'size': 12})
# ax.set_xticks([2, 3, 4, 5])
# ax.set_xticklabels([2, 3, 4, 5])
# # sns.despine()
 
# plt.legend(loc = 'upper right', title='Embedding dimension', fontsize=11, borderpad=1, framealpha=0)
# plt.grid(True, linestyle='--', alpha=0.5)
# # plt.show()

# plt.savefig('num_layers.pdf', dpi=300, format='pdf')

# %%
color1 = ['#F48E35', '#8FBDDF', '#FAE360', '#F06A8A']
color2 = ['#01CDFE', '#05FFA1', '#FF71CE', '#B967FF']

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams["figure.figsize"] = (5, 2)
plt.rcParams['lines.linewidth'] = 1.4

plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['axes.ymargin'] = 0.2
# plt.rcParams['legend.title_fontsize'] = 'small'
 
f, ax  = plt.subplots(1, 1)

# emb_64 = np.array([98.14, 98.10, 98.03, 98.05, 98.03])
# emb_72 = np.array([98.21, 98.23, 98.04, 98.01, 98.06])
# emb_96 = np.array([98.30, 98.31, 98.17, 98.20, 98.12])

# emb_64 = np.array([90.76, 91.33, 91.81, 90.98, 90.59])
# emb_72 = np.array([91.27, 92.18, 91.55, 91.12, 90.58])
# emb_96 = np.array([91.66, 91.88, 90.92, 91.13, 91.38])

emb_64 = np.array([0.982152, 0.981329, 0.979898, 0.980751]) * 100
emb_72 = np.array([0.982608, 0.982487, 0.981573, 0.982243]) * 100
emb_96 = np.array([0.984832, 0.984497, 0.984010, 0.982334]) * 100
# emb_128 = np.array([91.66, 91.88, 90.92, 91.13, 91.38]) * 100

concat = np.concatenate([emb_64, emb_72, emb_96]).reshape(3, len(emb_64))
print(concat)
emb_avg = np.mean(concat, axis=0)

print(emb_avg)

x = range(1, len(emb_avg)+1)

color = color2

plt.plot(x, emb_64, color = color[0], marker = 'o', markersize= 5, label = '64' )
plt.plot(x, emb_72, color = color[1], marker = 'o', markersize= 5, label = '72' )
plt.plot(x, emb_96, color = color[2], marker = 'o', markersize= 5, label = '96' )
# plt.plot(x, emb_128, color = '#F0F1DF', marker = 'o', markersize= 6, label = '128' )
plt.plot(x, emb_avg, color = color[-1], linestyle='--', marker = '^', markersize= 7, linewidth=2, label = 'average' )
# sns.lineplot(x = 'The number of layers', y = 'Energy consumption (uJ)', data = pd.DataFrame([10, 20, 30, 40]), color = 'b', marker = '^', markersize= 12, label = 'After No.1 sample')
 
#ax.set(xscale="log", yscale="linear")
#ax.get_xaxis().get_major_formatter().labelOnlyBase = False

ax.set_xlabel('The number of layers in Neocortex', fontdict={'size': 13})
ax.set_ylabel('Accuracy (%)', fontdict={'size': 13})
ax.set_xticks([1, 2, 3, 4])
ax.set_xticklabels([1, 2, 3, 4])
# ax.set_yticks([90.5, 91.0, 91.5, 92.0, 92.5])
ax.set_yticks([98.0, 98.1, 98.2, 98.3, 98.4, 98.5, 98.6])
# sns.despine()
 
# plt.legend(loc = 'upper right', title='Embedding dimension', fontsize=8, borderpad=1, framealpha=0, bbox_to_anchor=(1.0, 1.0))
ax.legend(title='Embedding dimension', prop={'size': 9}, bbox_to_anchor=(1.0, 1.0), title_fontsize=9)
plt.grid(True, linestyle='dotted', alpha=0.5)
# plt.show()

plt.savefig('num_layers.pdf', dpi=1200, format='pdf', bbox_inches = 'tight')
# Out:
# [[98.2152 98.1329 97.9898 98.0751]
#  [98.2608 98.2487 98.1573 98.2243]
#  [98.4832 98.4497 98.401  98.2334]]
# [98.31973333 98.2771     98.1827     98.1776    ]

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams["figure.figsize"] = (5, 2)
plt.rcParams['lines.linewidth'] = 1.4

plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['axes.ymargin'] = 0.2
# plt.rcParams['legend.title_fontsize'] = 'small'
 
f, ax  = plt.subplots(1, 1)

# emb_64 = np.array([98.14, 98.10, 98.03, 98.05, 98.03])
# emb_72 = np.array([98.21, 98.23, 98.04, 98.01, 98.06])
# emb_96 = np.array([98.30, 98.31, 98.17, 98.20, 98.12])

# emb_64 = np.array([90.76, 91.33, 91.81, 90.98, 90.59])
# emb_72 = np.array([91.27, 92.18, 91.55, 91.12, 90.58])
# emb_96 = np.array([91.66, 91.88, 90.92, 91.13, 91.38])

emb_64 = np.array([0.982152, 0.981329, 0.979898, 0.980751]) * 100
emb_72 = np.array([0.982608, 0.982487, 0.981573, 0.982243]) * 100
emb_96 = np.array([0.984832, 0.984497, 0.984010, 0.982334]) * 100
# emb_128 = np.array([91.66, 91.88, 90.92, 91.13, 91.38]) * 100

concat = np.concatenate([emb_64, emb_72, emb_96]).reshape(3, len(emb_64))
print(concat)
emb_avg = np.mean(concat, axis=0)

print(emb_avg)

x = range(1, len(emb_avg)+1)

color = color2

plt.plot(x, emb_64, color = color[0], marker = 'o', markersize= 5, label = '64' )
plt.plot(x, emb_72, color = color[1], marker = 'o', markersize= 5, label = '72' )
plt.plot(x, emb_96, color = color[2], marker = 'o', markersize= 5, label = '96' )
# plt.plot(x, emb_128, color = '#F0F1DF', marker = 'o', markersize= 6, label = '128' )
plt.plot(x, emb_avg, color = color[-1], linestyle='--', marker = '^', markersize= 7, linewidth=2, label = 'average' )
# sns.lineplot(x = 'The number of layers', y = 'Energy consumption (uJ)', data = pd.DataFrame([10, 20, 30, 40]), color = 'b', marker = '^', markersize= 12, label = 'After No.1 sample')
 
#ax.set(xscale="log", yscale="linear")
#ax.get_xaxis().get_major_formatter().labelOnlyBase = False

ax.set_xlabel('The number of layers in Neocortex', fontdict={'size': 13})
ax.set_ylabel('F1 score (%)', fontdict={'size': 13})
ax.set_xticks([1, 2, 3, 4])
ax.set_xticklabels([1, 2, 3, 4])
# ax.set_yticks([90.5, 91.0, 91.5, 92.0, 92.5])
# ax.set_yticks([98.0, 98.1, 98.2, 98.3, 98.4, 98.5, 98.6])
# sns.despine()
 
# plt.legend(loc = 'upper right', title='Embedding dimension', fontsize=8, borderpad=1, framealpha=0, bbox_to_anchor=(1.0, 1.0))
ax.legend(title='Embedding dimension', prop={'size': 9}, bbox_to_anchor=(1.0, 1.0), title_fontsize=9)
plt.grid(True, linestyle='dotted', alpha=0.5)
# plt.show()

plt.savefig('num_layers.pdf', dpi=1200, format='pdf', bbox_inches = 'tight')

# %%
spikformer_mssa_path = '/home/yschoi/snn/spiking_transformer_bincf/myModel/result/250305/250305+time_steps+20+time_num_layers+2+embed_dim+72+data_patch_size+16+stride+9+gating+ablation+alpha+0.1+attn+MSSA'
spikformer_mssa_path_acc_csv = pd.read_csv(spikformer_mssa_path + '/log/val.csv')

# %%
spikformer_ssa_path = '/home/yschoi/snn/spiking_transformer_bincf/myModel/result/250303/250303+time_steps+20+time_num_layers+2+embed_dim+72+data_patch_size+16+stride+9+alpha+0.1+gating+ablation+self_attn+SSA'
spikformer_ssa_path_acc_csv = pd.read_csv(spikformer_ssa_path + '/log/val.csv')

# %%
proposed_mssa_path = '/home/yschoi/snn/spiking_transformer_bincf/myModel/result/250305/250305+time_steps+20+time_num_layers+2+embed_dim+72+data_patch_size+16+stride+9+gating+original+alpha+0.1'
proposed_mssa_path_acc_csv = pd.read_csv(proposed_mssa_path + '/log/val.csv')

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams["figure.figsize"] = (6, 6)
plt.rcParams['lines.linewidth'] = 1.2

plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10
plt.rcParams['axes.ymargin'] = 0

x = range(0, 250)
f, ax  = plt.subplots(1, 1)

plt.plot(x, proposed_mssa_path_acc_csv.iloc[:, -1], color = '#4269D0FF', label = 'Proposed+MSSA')
plt.plot(x, spikformer_mssa_path_acc_csv.iloc[:, -1], color = '#EFB118FF', label = 'Spikformer+SSA')
# plt.plot(x, emb_72, color = '#EFB118FF', marker = 'o', markersize= 6, label = '72' )
# plt.plot(x, emb_96, color = '#FF8AB7FF', marker = 'o', markersize= 6, label = '96' )
# plt.plot(x, emb_128, color = 'gray', marker = 'o', markersize= 6, label = '128' )
# plt.plot(x, emb_avg, color = 'black', linestyle='--', marker = 'o', markersize= 6, label = 'average' )
# sns.lineplot(x = 'The number of layers', y = 'Energy consumption (uJ)', data = pd.DataFrame([10, 20, 30, 40]), color = 'b', marker = '^', markersize= 12, label = 'After No.1 sample')
 
#ax.set(xscale="log", yscale="linear")
#ax.get_xaxis().get_major_formatter().labelOnlyBase = False

ax.set_xlabel('Epoch', fontdict={'size': 12})
ax.set_ylabel('Acc (%)', fontdict={'size': 12})
# ax.set_ylim((0, 1))
ax.set_yscale('linear')
ax.set_xscale('linear')
# ax.set_xticks([1, 2, 3, 4, 5])
# ax.set_xticklabels([1, 2, 3, 4, 5])
# ax.set_yticks([90.5, 91.0, 91.5, 92.0, 92.5])
# ax.set_yticks([98.0, 98.1, 98.2, 98.3, 98.4, 98.5])
# sns.despine()
plt.legend(loc = 'upper right', title='Embedding dimension', fontsize=10, borderpad=1, framealpha=0)
plt.grid(True, linestyle='dotted', alpha=0.5)
# plt.show()
current_values = plt.gca().get_yticks()
# plt.gca().set_yticklabels(['{:.0%}'.format(x) for x in current_values])
plt.savefig('ablation_epoch_acc.pdf', dpi=1200, format='pdf', bbox_inches = 'tight')
